# %% [markdown]
# # Pipelines

# %% [markdown]
# data yang digunakan adalah https://drive.google.com/file/d/1meMmfU6hnNBZWhwxwkPDhU5-uQUSWPlY/view?usp=sharing

# %% [markdown]
# 1. langkah instal requrement dan diletakkan diEnvironments

# %%
#!/bin/bash

# Install any dependencies you have in this shell script,
# see https://docs.orchest.io/en/latest/fundamentals/environments.html#install-packages
pip install jupyterlab_code_formatter
pip install pandas scikit-learn pyscopg2-binary
# E.g. mamba install -y tensorflow
pip install typing
# pip install SQLAlchemy
pip install pandas
pip install scikit-learn
pip install psycopg2-binary
pip install sqlalchemy

# %% [markdown]
# 2. Import modul modul yang diperlukan

# %%
import os
import urllib.parse as up
import orchest
import psycopg2
import pandas as pd
from sklearn import datasets
import sqlalchemy as db
from sqlalchemy import create_engine

# %%
up.uses_netloc.append("postgres")
url = up.urlparse("postgres://nopxmrfi:fqMuEpdxZU6FuNgyevJE_qMaw5Ncl0mS@floppy.db.elephantsql.com/nopxmrfi")
conn = psycopg2.connect(dbname=url.path[1:], user=url.username, password=url.password, host=url.hostname, port=url.port)

engine = create_engine("postgresql+psycopg2://nopxmrfi:fqMuEpdxZU6FuNgyevJE_qMaw5Ncl0mS@floppy.db.elephantsql.com/nopxmrfi")
connection = engine.connect()
metadata = db.MetaData()
iris_data = db.Table('iris_data', metadata, autoload=True, autoload_with=engine)
elephantsql_db = db.Table('iris_data', metadata, autoload=True, autoload_with=engine)

query = db.select([elephantsql_db.columns.id, elephantsql_db.columns.sepal_length])
results = connection.execute(query).fetchall()
df = pd.DataFrame(results)
df.columns = results[0].keys()
df.head(5)
